# %% [markdown]
# Educación

# %%
! pip install -U pandasql
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-e7be18c1-f09b-4f98-b101-0d6a7c936f73" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e7be18c1-f09b-4f98-b101-0d6a7c936f73">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving noticias_derechos10.csv to noticias_derechos10.csv

# %%
####  educacion
import pandas as pd
from pandasql import sqldf
mysql = lambda q: sqldf(q, globals())
df=pd.read_csv('noticias_derechos10.csv')
df = mysql("""SELECT * FROM df WHERE ((date) BETWEEN '2021-07-04' AND '2022-07-27') AND (LOWER(body) LIKE LOWER ('%Convención%') AND LOWER(body) LIKE LOWER ('%Constitu%') AND body LIKE '%derecho%' AND body LIKE '%educación%'
OR LOWER(body) LIKE LOWER ('%Nueva%') AND LOWER(body) LIKE LOWER ('%Constitución%') AND body LIKE '%derecho%'  AND body LIKE '%educación%')
ORDER BY date""")
df
# Out:
#       Unnamed: 0        date  \
# 0              3  2021-07-04
# 1              7  2021-07-04
# 2             10  2021-07-04
# 3             12  2021-07-04
# 4             13  2021-07-04
# ...          ...         ...
# 2389        5756  2022-07-26
# 2390        5759  2022-07-26
# 2391        5762  2022-07-26
# 2392        5768  2022-07-27
# 2393        5771  2022-07-27
#
#                                                   title  \
# 0     [INTERACTIVO] La Convención en Cifras: el peso...
# 1     Hacia un nuevo pacto "socio- espacial" - La Te...
# 2     Elisa Loncon: ¿Cuáles son las credenciales de ...
# 3     El proyecto constitucional de Michelle Bachele...
# 4                  Una constitución como un 'Nunca Más'
# ...                                                 ...
# 2389  Vodanovic: "AD no tiene reparo con hacer cambi...
# 2390  Alta valoracion en dirigencias gremiales y sin...
# 2391  Inauguraron la "Casa Ciudadana por el Rechazo"...
# ...

# %%
###### Numero de medios 
medios = df['title_1'].unique()
medios = pd.DataFrame(medios)
medios
# Out:
#                                                     0
# 0                                     T13 (teletrece)
# 1                                          LA TERCERA
# 2                                          publimetro
# 3                                         BioBioChile
# 4                                        El Ciudadano
# 5           Diario Lanalhue Noticias (Cañete - Chile)
# 6                  https://www.facebook.com/el.dinamo
# 7                                              La Red
# 8                                        El Mostrador
# 9                                      Diario Longino
# 10               102.5 FM, Radio Universidad de Chile
# 11  The Clinic - Reportajes, noticias, podcast, vi...
# 12                                          La Nación
# 13                                              Finde
# 14                                  24horas.cl - Home
# 15                                       CIPER Chile
# ...

# %%
#### conteo de medios 
freq2 = df['title_1'].value_counts() 
conteo_medios = pd.DataFrame(freq2) 
conteo_medios
# Out:
#                                                     title_1
# LA TERCERA                                              423
# El Mostrador                                            400
# El Ciudadano                                            270
# 102.5 FM, Radio Universidad de Chile                    172
# The Clinic - Reportajes, noticias, podcast, vid...      146
# BioBioChile                                             118
# Diario Financiero                                       115
# 24horas.cl - Home                                        84
# T13 (teletrece)                                          69
# CIPER Chile                                              61
# Cooperativa                                              55
# https://www.facebook.com/el.dinamo                       50
# La Nación                                                50
# RadioAgricultura                                         41
# La prensa Austral Punta Arenas                           40
# ...

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df_xsemana = df.assign(N_noticias=1) ## crear columna con 1
df_xsemana = df_xsemana.loc[:,['date','N_noticias']] ##### seleccion de columnas para df
df_xsemana = df_xsemana.groupby(pd.Grouper(key='date', axis=0, 
                      freq='7D', sort=True)).sum()          ##### agrupa x semana y suma
df_xsemana
# Out:
#             N_noticias
# date
# 2021-07-04          45
# 2021-07-11          28
# 2021-07-18          32
# 2021-07-25          20
# 2021-08-01          19
# 2021-08-08          22
# 2021-08-15          27
# 2021-08-22          31
# 2021-08-29          23
# 2021-09-05          36
# 2021-09-12          56
# 2021-09-19          30
# 2021-09-26          40
# 2021-10-03          31
# 2021-10-10          42
# 2021-10-17          52
# 2021-10-24          63
# 2021-10-31          38
# 2021-11-07          42
# 2021-11-14          40
# 2021-11-21          39
# 2021-11-28          32
# 2021-12-05          42
# 2021-12-12          46
# 2021-12-19          44
# 2021-12-26          36
# 2022-01-02          45
# 2022-01-09          53
# 2022-01-16          51
# 2022-01-23          55
# 2022-01-30          39
# 2022-02-06          30
# 2022-02-13          30
# 2022-02-20          53
# 2022-02-27          38
# 2022-03-06          82
# 2022-03-13          63
# 2022-03-20          52
# ...

# %%
df_xsemana.to_csv('educacion_noticias_xsemanas.csv')
files.download('educacion_noticias_xsemanas.csv')

# %%
### graficar
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns

sns.lineplot(data = df_xsemana)

# %%
### union de df por columnas
df_simbolos_total = pd.concat([simbolos_informa, simbolos_desinfo], axis=0)
df_simbolos_total

# %%
##### grafico manual (opcional)
fig, ax = plt.subplots()
semanas = ['1','2','3','4','5','6','7']
columnas = {'N noticias':[41,31,38,66,93,69,48]}
ax.plot(semanas, columnas['N noticias'], label = 'Noticias')
ax.set_title('Volumen de noticias con mención a la paridad de género', loc = "left", fontdict = {'fontsize':8, 'fontweight':'bold', 'color':'tab:blue'})
plt.xlabel("Semanas (04 jun - 21 jul)")
plt.ylabel("Numero de noticias")

ax.legend(loc = 'upper right')
plt.savefig('volumen_noticias_paridad.pdf',  dpi=800)

plt.show()
